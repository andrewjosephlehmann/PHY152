# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# With the numpy module, we can use functions such as sine and cosine #

#For example, this is the graph of the function sin(x), with various amplitudes#

x = np.linspace(-np.pi,np.pi,100000)

# the function, which is y = sin(x) here
y = np.sin(x)

# %%
#Here is where we use matplotlib to graph our function
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the functions
plt.plot(x,y, 'b', label='y=sin(x)')
plt.plot(x,2*y, 'c', label='y=2sin(x)')
plt.plot(x,3*y, 'r', label='y=3sin(x)')

plt.legend(loc='upper left')

# show the plot
plt.show()

# %%
# We can also graph cos(x), with various amplitudes #

y = np.cos(x)

# %%
#Here is where we use matplotlib to graph our function
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the functions
plt.plot(x,y, 'b', label='y=cos(x)')
plt.plot(x,2*y, 'c', label='y=2cos(x)')
plt.plot(x,3*y, 'r', label='y=3cos(x)')

plt.legend(loc='upper left')

# show the plot
plt.show()

# %%
# Defining functions #

def addTwo(x):
    return x + 2
answer = addTwo(1)
print(answer)
# Out:
# 3

# %%
#Now we can add two to any number we insert not variable x :)#
#e.g.#
a2 = addTwo(2)
print('Adding two to two equals', a2)
# Out:
# Adding two to two equals 4

# %%
#For pi day.#
piminustwo = np.pi - 2
pi = addTwo(piminustwo)
print('The ratio of the circumference to its diameter equals', pi)
# Out:
# The ratio of the circumference to its diameter equals 3.141592653589793

# %%
#Creating a different function#
def multipleofpi(x): 
    return np.pi*x
#Let us verify if it outputs a multiple of pi. Since my birthday is a multiple of pi, 6.28, let us choose x = 2.#
tau = multipleofpi(2)
print(tau)
# Out:
# 6.283185307179586

# %%
#A sine wave without an offset of theta: $A\sin(\omega t)$#
#We shall call this function sineWaveZero#

def sineWaveZero (Amplitude, Omega, time): 
    return Amplitude * np.sin(-Omega*time)
#Let us verify this, when each variable equals one#
print(sineWaveZero(1, 1, 1))
# Out:
# -0.8414709848078965

# %%
#Example graph for our function#
t = np.linspace(-np.pi,np.pi,100000)
y = sineWaveZero(1, 1, t)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')



# plot the functions
plt.plot(t,y, label='f(t)=$A\sin$($-\omega t$)')
plt.legend(loc='upper left')


# show the plot
plt.show()

# %%
#Example graph for our function, different variables according to instructions from practical#
dt = 0.001
t = np.arange(0,100,dt)
omega1 = 5 #rad/s# 
omega2 = 5.4
amplitude = 3
y = sineWaveZero(amplitude, omega1, t)
ydelta = sineWaveZero(amplitude, omega1, t)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')



# plot the functions
plt.plot(t,y, label='f(t)=$3\sin$($-(5rad/s) t$)')
plt.legend(loc='upper left')


# show the plot
plt.show()

# %%
#difference of omega by 0.4$
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(t,y, label='f(t)=$4\sin(-(5.4rad/s)t)')
plt.legend(loc='upper left')

# %%
#Example graph for our function, different variables according to instructions from practical#
dt = 0.001
t = np.arange(0,np.pi,dt)
omega1 = 5 #rad/s# 
omega2 = 5.4
amplitude = 3
y = sineWaveZero(amplitude, omega1, t)
ydelta = sineWaveZero(amplitude, omega2, t)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')



# plot the functions
plt.plot(t,y, label='f$_1$(t)=$3\sin$($-(5rad/s) t$)')
plt.plot(t,ydelta, label='f$_2$(t)=$4\sin(-(5.4rad/s)t$)')
plt.plot(t,y+ydelta, label='f$_{1+2}$(t)')

plt.legend(loc='upper left')


# show the plot

# %%
#Defining a different function# 
#We shall call this function sineWaveZerPhi#

def sineWaveZeroPhi (Amplitude, Wavenumber, Position, Omega, time): 
    return Amplitude * np.sin(Wavenumber*Position-Omega*time)
#Let us verify this, when each variable equals one#
print(sineWaveZeroPhi(1, 1, 1,1,1))
# Out:
# 0.0

# %%
numbers = [1,5,3,6]
for number in numbers:
    print(number)
# Out:
# 1
# 5
# 3
# 6

# %%
words = "hizmyznameziszAndrewzLehmann"
words.split('z')
# Out:
# ['hi', 'my', 'name', 'is', 'Andrew', 'Lehmann']

# %%
L = [[2,4],[3,8],[6,7]]

for i in range(len(L)):
     L[i][1] = 7
print(L)
# Out:
# [[2, 7], [3, 7], [6, 7]]

# %%
x = np.linspace(0,10,1000)

# %%
fig, (ax1) = plt.subplots(1, 1, sharex=True, sharey=True)
fig.suptitle('Wave Functions')

ax1.set_xlim(0, 2*np.pi)
ax1.set_ylim(-4, 4)

line1, = ax1.plot([], [], color='r', lw=2)
line2, = ax1.plot([], [], color='g', lw=2)
line3, = ax1.plot([], [], color='b', lw=2)
plt.legend([line1, line2, line3],['$y_1(x,t)=$$\sin$(($\pi/2$)$x-2\pi t$)', '$y_2(x,t)=$$\sin$(($\pi/2$)$x+2\pi t$)', '$y_3(x,t)$ = $y_1+y_2$'])

# %%
def init():
        line1.set_data([], [])
        line2.set_data([], [])
        line3.set_data([], [])
        return line1, line2, line3

# %%
def animate(i):
        x = np.linspace(0,10,100000)
        y1 = sineWaveZeroPhi(1,np.pi/2, x, 2*np.pi, 0.01*i)
        line1.set_data(x, y1)

        y2 = sineWaveZeroPhi(1,np.pi/2, x, -2*np.pi, 0.01*i)
        line2.set_data(x, y2)

        y3 = y1+y2
        line3.set_data(x,y3)

        return line1, line2, line3

# %%
anim1 = FuncAnimation(fig, animate, init_func=init,
                     frames=100, interval=100, blit=True)

anim1.save('combined_sine_wave.gif', writer='imagemagick')
